# %%
import mapvbvd

twix = mapvbvd.mapVBVD("meas_MID182_cMESSsTR_FID14929.dat");
# Out:
# pymapVBVD version 0+unknown
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/1.53G [00:00<?, ?B/s]

# %%
twix.image.flagRemoveOS = False
data = twix.image[''];
# Out:
# read data:   0%|          | 0/12500 [00:00<?, ?it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
data.shape
# Out:
# (248, 32, 250, 10, 1, 1, 1, 1, 5, 1, 1, 1, 1, 1, 1, 1)

# %%
d = np.squeeze(np.array(data))

plt.imshow(np.abs(np.fft.fftshift(np.fft.ifft2(np.fft.ifftshift(np.squeeze(d[:,1,:,5,1]))))))
